# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_178/4008145293.py in <cell line: 0>()
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
# Cell 1 — Install missing libraries
# !pip install imbalanced-learn openpyxl -q

# %%
# Cell 2 — Train the model
# !python train.py --data alzheimers_disease_data.xlsx
# Out:
# 2026-03-16 12:09:41.559631: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-16 12:09:41.564972: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-16 12:09:41.578016: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773662981.602222    5276 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773662981.609744    5276 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import os
files = os.listdir('/content')
data_files = [f for f in files if f.endswith('.csv') or f.endswith('.xlsx')]
print("Data files found:", data_files)
# Out:
# Data files found: ['alzheimers_disease_data.csv']

# %%
# !python train.py --data alzheimers_disease_data.csv
# Out:
# 2026-03-16 12:14:19.779777: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-16 12:14:19.787037: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-16 12:14:19.808823: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773663259.846731    6395 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773663259.857872    6395 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Cell 4 — Confirm outputs were created
import os
for root, dirs, files in os.walk("outputs"):
    for f in files:
        print(os.path.join(root, f))
# Out:
# outputs/feature_names.pkl
# outputs/scaler.pkl
# outputs/training_log.csv
# outputs/checkpoints/best_model.keras
# outputs/checkpoints/final_model.keras
# outputs/plots/confusion_matrix.png
# outputs/plots/feature_importance.png
# outputs/plots/training_curves.png
# outputs/plots/roc_pr_curves.png

# %%
# Cell 5 — Display all result plots
from IPython.display import Image, display
display(Image("outputs/plots/training_curves.png"))
display(Image("outputs/plots/confusion_matrix.png"))
display(Image("outputs/plots/roc_pr_curves.png"))
display(Image("outputs/plots/feature_importance.png"))
